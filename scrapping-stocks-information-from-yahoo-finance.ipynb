# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import requests
from bs4 import BeautifulSoup as bs
from string import ascii_uppercase

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
def get_symbols_from_alphabet(alpha):
    r = requests.get('http://www.eoddata.com/stocklist/TSX/{}.htm'.format(alpha))
    soup = bs(r.content)
    div = soup.find('div', attrs={'id': 'col1w'})
    table = div.find('table', attrs={'class': 'quotes'})
    quotes = table.find_all('a')
    return [quote.text for quote in quotes if quote.text != '']

# %%
def get_stats_from_symbol(symbol):
    r = requests.get('https://finance.yahoo.com/quote/{}/key-statistics'.format(symbol))
    soup = bs(r.content)
    
    stats = {}
    
    if soup.find('table', class_='W(100%) Bdcl(c) M(0) Whs(n) BdEnd Bdc($seperatorColor) D(itb)') != None:
        # name
        name = soup.find('h1', class_='D(ib) Fz(18px)').text 

        stats['name'] = name

        # valuation measures
        vm_table = soup.find('table', attrs={'class': 'W(100%) Bdcl(c) M(0) Whs(n) BdEnd Bdc($seperatorColor) D(itb)'})
        key_rows = vm_table.find_all('td', class_=lambda c: c and c.startswith('Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)'))
        keys = [row.find('span').text for row in key_rows]

        value_rows = vm_table.find_all('td', attrs={'class': 'Ta(c) Pstart(10px) Miw(60px) Miw(80px)--pnclg Bgc($lv1BgColor) fi-row:h_Bgc($hoverBgColor)'})
        values = [row.text for row in value_rows]

        for i in range(len(keys)):
            stats[keys[i]] = values[i]

        # financial highlights
        fh_div = soup.find('div', attrs={'class': 'Mb(10px) Pend(20px) smartphone_Pend(0px)'})
        key_rows = fh_div.find_all('td', class_=lambda c: c and c.startswith('Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)'))
        keys = [row.find('span').text for row in key_rows]

        value_rows = fh_div.find_all('td', class_='Fw(500) Ta(end) Pstart(10px) Miw(60px)')
        values = [row.text if row.text != None else row.find('span').text for row in value_rows]

        for i in range(len(keys)):
            stats[keys[i]] = values[i]

        # trading_information
        ti_div = soup.find('div', class_='Pstart(20px) smartphone_Pstart(0px)')
        key_rows = ti_div.find_all('td', class_=lambda c: c and c.startswith('Pos(st) Start(0) Bgc($lv2BgColor) fi-row:h_Bgc($hoverBgColor) Pend(10px)'))
        keys = [row.find('span').text for row in key_rows]

        value_rows = ti_div.find_all('td', class_='Fw(500) Ta(end) Pstart(10px) Miw(60px)')
        values = [row.text if row.text != None else row.find('span').text for row in value_rows]

        for i in range(len(keys)):
            stats[keys[i]] = values[i]

    return stats

# %%
infos = []

for alpha in ascii_uppercase[:10]:
    symbols = get_symbols_from_alphabet(alpha)
    temp = [get_stats_from_symbol(symbol) for symbol in symbols]
    infos += [info for info in temp if info]
    print(alpha, len(infos))
infos
# Out:
# A 30
# B 45
# C 52
# D 52
# E 52
# F 52
# G 52
# H 52
# I 52
# J 52
# [{'name': 'Abbott Laboratories (ABT)',
#   'Market Cap (intraday)': '178.68B',
#   'Enterprise Value': '193.32B',
#   'Trailing P/E': '58.67',
#   'Forward P/E': '23.15',
#   'PEG Ratio (5 yr expected)': '3.21',
#   'Price/Sales': '5.72',
#   'Price/Book': '5.84',
#   'Enterprise Value/Revenue': '6.15',
#   'Enterprise Value/EBITDA': '26.60',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '9.89%',
#   'Operating Margin': '14.00%',
#   'Return on Assets': '4.01%',
#   'Return on Equity': '9.86%',
#   'Revenue': '31.44B',
#   'Revenue Per Share': '17.76',
#   'Quarterly Revenue Growth': '-8.20%',
#   'Gross Profit': '18.71B',
#   'EBITDA': '7.57B',
#   'Net Income Avi to Common': '3.07B',
#   'Diluted EPS': '1.73',
#   'Quarterly Earnings Growth': '-46.60%',
#   'Total Cash': '5.04B',
#   'Total Cash Per Share': '2.85',
#   'Total Debt': '19.68B',
#   'Total Debt/Equity': '63.90',
#   'Current Ratio': '1.57',
#   'Book Value Per Share': '17.27',
#   'Operating Cash Flow': '6.4B',
#   'Levered Free Cash Flow': '4.68B',
#   'Beta (5Y Monthly)': '0.91',
#   '52-Week Change': '31.42%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '114.20',
#   '52 Week Low': '61.61',
#   '50-Day Moving Average': '105.02',
#   '200-Day Moving Average': '94.61',
#   'Avg Vol (3 month)': '5.36M',
#   'Avg Vol (10 day)': '6.23M',
#   'Shares Outstanding': '1.77B',
#   'Float': '1.76B',
#   '% Held by Insiders': '0.73%',
#   '% Held by Institutions': '77.18%',
#   'Shares Short (Sep 14, 2020)': '8.68M',
#   'Short Ratio (Sep 14, 2020)': '1.32',
#   'Short % of Float (Sep 14, 2020)': '0.50%',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '0.49%',
#   'Shares Short (prior month Aug 13, 2020)': '10.09M',
#   'Forward Annual Dividend Rate': '1.44',
#   'Forward Annual Dividend Yield': '1.35%',
#   'Trailing Annual Dividend Rate': '1.40',
#   'Trailing Annual Dividend Yield': '1.31%',
#   '5 Year Average Dividend Yield': '1.90',
#   'Payout Ratio': '79.07%',
#   'Dividend Date': 'Nov 15, 2020',
#   'Ex-Dividend Date': 'Oct 13, 2020',
#   'Last Split Factor': '10000:4798',
#   'Last Split Date': 'Jan 01, 2013'},
#  {'name': 'Associated Capital Group, Inc. (AC)',
#   'Market Cap (intraday)': '778.64M',
#   'Enterprise Value': '704.23M',
#   'Trailing P/E': '20.78',
#   'Forward P/E': 'N/A',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '26.69',
#   'Price/Book': '0.91',
#   'Enterprise Value/Revenue': '24.04',
#   'Enterprise Value/EBITDA': '-25.21',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '-72.17%',
#   'Operating Margin': '-34.03%',
#   'Return on Assets': '-0.64%',
#   'Return on Equity': '-2.37%',
#   'Revenue': '29.3M',
#   'Revenue Per Share': '1.30',
#   'Quarterly Revenue Growth': '-34.90%',
#   'Gross Profit': '-919k',
#   'EBITDA': '-9.92M',
#   'Net Income Avi to Common': '-21.14M',
#   'Diluted EPS': '-0.94',
#   'Quarterly Earnings Growth': 'N/A',
#   'Total Cash': '393.78M',
#   'Total Cash Per Share': '17.61',
#   'Total Debt': 'N/A',
#   'Total Debt/Equity': 'N/A',
#   'Current Ratio': '20.82',
#   'Book Value Per Share': '38.09',
#   'Operating Cash Flow': '-263.22M',
#   'Levered Free Cash Flow': '-52.36M',
#   'Beta (5Y Monthly)': '1.25',
#   '52-Week Change': '-8.18%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '65.13',
#   '52 Week Low': '24.21',
#   '50-Day Moving Average': '37.34',
#   '200-Day Moving Average': '36.43',
#   'Avg Vol (3 month)': '17.16k',
#   'Avg Vol (10 day)': '11.42k',
#   'Shares Outstanding': '3.4M',
#   'Float': '3.27M',
#   '% Held by Insiders': '3.95%',
#   '% Held by Institutions': '85.20%',
#   'Shares Short (Sep 14, 2020)': '63.09k',
#   'Short Ratio (Sep 14, 2020)': '4.66',
#   'Short % of Float (Sep 14, 2020)': '3.46%',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '0.28%',
#   'Shares Short (prior month Aug 13, 2020)': '78.64k',
#   'Forward Annual Dividend Rate': '0.2',
#   'Forward Annual Dividend Yield': '0.57%',
#   'Trailing Annual Dividend Rate': '0.20',
#   'Trailing Annual Dividend Yield': '0.55%',
#   '5 Year Average Dividend Yield': 'N/A',
#   'Payout Ratio': 'N/A',
#   'Dividend Date': 'Jun 29, 2020',
#   'Ex-Dividend Date': 'Jun 14, 2020',
#   'Last Split Factor': '1005:1000',
#   'Last Split Date': 'Jul 28, 2020'},
#  {'name': 'Aurora Cannabis Inc. (ACB)',
#   'Market Cap (intraday)': '562.90M',
#   'Enterprise Value': '833.34M',
#   'Trailing P/E': 'N/A',
#   'Forward P/E': 'N/A',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '2.15',
#   'Price/Book': '0.35',
#   'Enterprise Value/Revenue': '2.99',
#   'Enterprise Value/EBITDA': '-0.26',
#   'Fiscal Year Ends': 'Jun 29, 2020',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '0.00%',
#   'Operating Margin': '0.00%',
#   'Return on Assets': '-7.31%',
#   'Return on Equity': '-101.34%',
#   'Revenue': 'N/A',
#   'Revenue Per Share': 'N/A',
#   'Quarterly Revenue Growth': 'N/A',
#   'Gross Profit': '-33.54M',
#   'EBITDA': 'N/A',
#   'Net Income Avi to Common': 'N/A',
#   'Diluted EPS': '0.2160',
#   'Quarterly Earnings Growth': 'N/A',
#   'Total Cash': 'N/A',
#   'Total Cash Per Share': 'N/A',
#   'Total Debt': 'N/A',
#   'Total Debt/Equity': '24.98',
#   'Current Ratio': '1.54',
#   'Book Value Per Share': '3.44',
#   'Operating Cash Flow': 'N/A',
#   'Levered Free Cash Flow': 'N/A',
#   'Beta (5Y Monthly)': '1.51',
#   '52-Week Change': '-90.71%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '52.4640',
#   '52 Week Low': '4.5000',
#   '50-Day Moving Average': '7.6182',
#   '200-Day Moving Average': '10.3001',
#   'Avg Vol (3 month)': '4.83M',
#   'Avg Vol (10 day)': '8.85M',
#   'Shares Outstanding': '121.53M',
#   'Float': '120.92M',
#   '% Held by Insiders': '2.90%',
#   '% Held by Institutions': '12.27%',
#   'Shares Short (Sep 14, 2020)': '23.38M',
#   'Short Ratio (Sep 14, 2020)': '7.51',
#   'Short % of Float (Sep 14, 2020)': 'N/A',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '20.29%',
#   'Shares Short (prior month Aug 13, 2020)': '17.52M',
#   'Forward Annual Dividend Rate': 'N/A',
#   'Forward Annual Dividend Yield': 'N/A',
#   'Trailing Annual Dividend Rate': 'N/A',
#   'Trailing Annual Dividend Yield': 'N/A',
#   '5 Year Average Dividend Yield': 'N/A',
#   'Payout Ratio': '0.00%',
#   'Dividend Date': 'N/A',
#   'Ex-Dividend Date': 'N/A',
#   'Last Split Factor': '1:12',
#   'Last Split Date': 'May 10, 2020'},
#  {'name': 'Agnico Eagle Mines Limited (AEM)',
#   'Market Cap (intraday)': '19.15B',
#   'Enterprise Value': '20.56B',
#   'Trailing P/E': '38.46',
#   'Forward P/E': '20.75',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '7.20',
#   'Price/Book': '3.67',
#   'Enterprise Value/Revenue': '7.71',
#   'Enterprise Value/EBITDA': '14.11',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '18.46%',
#   'Operating Margin': '34.54%',
#   'Return on Assets': '6.71%',
#   'Return on Equity': '9.96%',
#   'Revenue': '2.67B',
#   'Revenue Per Share': '11.12',
#   'Quarterly Revenue Growth': '5.80%',
#   'Gross Profit': '1.26B',
#   'EBITDA': '1.15B',
#   'Net Income Avi to Common': '492.1M',
#   'Diluted EPS': '2.05',
#   'Quarterly Earnings Growth': '279.20%',
#   'Total Cash': '514.39M',
#   'Total Cash Per Share': '2.13',
#   'Total Debt': '1.92B',
#   'Total Debt/Equity': '36.76',
#   'Current Ratio': '3.27',
#   'Book Value Per Share': '21.67',
#   'Operating Cash Flow': '932.71M',
#   'Levered Free Cash Flow': '-22.74M',
#   'Beta (5Y Monthly)': '0.90',
#   '52-Week Change': '47.32%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '89.23',
#   '52 Week Low': '31.00',
#   '50-Day Moving Average': '80.77',
#   '200-Day Moving Average': '66.27',
#   'Avg Vol (3 month)': '1.41M',
#   'Avg Vol (10 day)': '1.08M',
#   'Shares Outstanding': '241.6M',
#   'Float': '240.94M',
#   '% Held by Insiders': '0.12%',
#   '% Held by Institutions': '76.25%',
#   'Shares Short (Sep 14, 2020)': '2.54M',
#   'Short Ratio (Sep 14, 2020)': '2.3',
#   'Short % of Float (Sep 14, 2020)': '1.15%',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '1.05%',
#   'Shares Short (prior month Aug 13, 2020)': '3.89M',
#   'Forward Annual Dividend Rate': '0.8',
#   'Forward Annual Dividend Yield': '1.01%',
#   'Trailing Annual Dividend Rate': '0.70',
#   'Trailing Annual Dividend Yield': '0.88%',
#   '5 Year Average Dividend Yield': '0.95',
#   'Payout Ratio': '33.82%',
#   'Dividend Date': 'Sep 14, 2020',
#   'Ex-Dividend Date': 'Nov 23, 2020',
#   'Last Split Factor': 'N/A',
#   'Last Split Date': 'N/A'},
#  {'name': 'Aeterna Zentaris Inc. (AEZS)',
#   'Market Cap (intraday)': '21.54M',
#   'Enterprise Value': '15.02M',
#   'Trailing P/E': 'N/A',
#   'Forward P/E': 'N/A',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '4.79',
#   'Price/Book': '22.96',
#   'Enterprise Value/Revenue': '10.29',
#   'Enterprise Value/EBITDA': '-5.14',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '-274.71%',
#   'Operating Margin': '-490.20%',
#   'Return on Assets': '-23.27%',
#   'Return on Equity': 'N/A',
#   'Revenue': '1.46M',
#   'Revenue Per Share': '0.07',
#   'Quarterly Revenue Growth': '-64.90%',
#   'Gross Profit': '122k',
#   'EBITDA': '-7.12M',
#   'Net Income Avi to Common': '-4.01M',
#   'Diluted EPS': '-0.2050',
#   'Quarterly Earnings Growth': 'N/A',
#   'Total Cash': '6.74M',
#   'Total Cash Per Share': '0.29',
#   'Total Debt': '222k',
#   'Total Debt/Equity': '23.84',
#   'Current Ratio': '3.58',
#   'Book Value Per Share': '0.04',
#   'Operating Cash Flow': '-10.4M',
#   'Levered Free Cash Flow': '-7.39M',
#   'Beta (5Y Monthly)': '2.16',
#   '52-Week Change': '-63.27%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '1.5400',
#   '52 Week Low': '0.3300',
#   '50-Day Moving Average': '0.4135',
#   '200-Day Moving Average': '0.6616',
#   'Avg Vol (3 month)': '4.97M',
#   'Avg Vol (10 day)': '1.04M',
#   'Shares Outstanding': '62.68M',
#   'Float': '23.56M',
#   '% Held by Insiders': '0.03%',
#   '% Held by Institutions': '10.82%',
#   'Shares Short (Sep 14, 2020)': '1.82M',
#   'Short Ratio (Sep 14, 2020)': '0.5',
#   'Short % of Float (Sep 14, 2020)': '2.90%',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '2.90%',
#   'Shares Short (prior month Aug 13, 2020)': '1.7M',
#   'Forward Annual Dividend Rate': 'N/A',
#   'Forward Annual Dividend Yield': 'N/A',
#   'Trailing Annual Dividend Rate': 'N/A',
#   'Trailing Annual Dividend Yield': 'N/A',
#   '5 Year Average Dividend Yield': 'N/A',
#   'Payout Ratio': '0.00%',
#   'Dividend Date': 'N/A',
#   'Ex-Dividend Date': 'N/A',
#   'Last Split Factor': '1:100',
#   'Last Split Date': 'Nov 19, 2015'},
#  {'name': 'Alamos Gold Inc. (AGI)',
#   'Market Cap (intraday)': '3.43B',
#   'Enterprise Value': '3.30B',
#   'Trailing P/E': '63.63',
#   'Forward P/E': '13.28',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '5.22',
#   'Price/Book': '1.28',
#   'Enterprise Value/Revenue': '4.98',
#   'Enterprise Value/EBITDA': '11.82',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '8.32%',
#   'Operating Margin': '21.74%',
#   'Return on Assets': '2.64%',
#   'Return on Equity': '2.07%',
#   'Revenue': '662M',
#   'Revenue Per Share': '1.69',
#   'Quarterly Revenue Growth': '-24.90%',
#   'Gross Profit': '327.7M',
#   'EBITDA': '290.8M',
#   'Net Income Avi to Common': '55.1M',
#   'Diluted EPS': '0.14',
#   'Quarterly Earnings Growth': '-50.40%',
#   'Total Cash': '231.5M',
#   'Total Cash Per Share': '0.59',
#   'Total Debt': '100.5M',
#   'Total Debt/Equity': '3.74',
#   'Current Ratio': '3.81',
#   'Book Value Per Share': '6.86',
#   'Operating Cash Flow': '251.9M',
#   'Levered Free Cash Flow': '-86.62M',
#   'Beta (5Y Monthly)': '1.53',
#   '52-Week Change': '50.00%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '11.58',
#   '52 Week Low': '3.34',
#   '50-Day Moving Average': '9.73',
#   '200-Day Moving Average': '8.66',
#   'Avg Vol (3 month)': '2.86M',
#   'Avg Vol (10 day)': '1.86M',
#   'Shares Outstanding': '391.43M',
#   'Float': '389.73M',
#   '% Held by Insiders': '0.30%',
#   '% Held by Institutions': '81.79%',
#   'Shares Short (Sep 14, 2020)': '3.32M',
#   'Short Ratio (Sep 14, 2020)': '1.42',
#   'Short % of Float (Sep 14, 2020)': 'N/A',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '0.85%',
#   'Shares Short (prior month Aug 13, 2020)': '3.16M',
#   'Forward Annual Dividend Rate': '0.06',
#   'Forward Annual Dividend Yield': '0.68%',
#   'Trailing Annual Dividend Rate': '0.05',
#   'Trailing Annual Dividend Yield': '0.57%',
#   '5 Year Average Dividend Yield': '0.48',
#   'Payout Ratio': '36.11%',
#   'Dividend Date': 'Sep 29, 2020',
#   'Ex-Dividend Date': 'Sep 14, 2020',
#   'Last Split Factor': 'N/A',
#   'Last Split Date': 'N/A'},
#  {'name': 'A.H. Belo Corporation (AHC)',
#   'Market Cap (intraday)': '32.95M',
#   'Enterprise Value': '15.85M',
#   'Trailing P/E': '3.62',
#   'Forward P/E': 'N/A',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '0.18',
#   'Price/Book': '0.65',
#   'Enterprise Value/Revenue': '0.10',
#   'Enterprise Value/EBITDA': '-2.20',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '-6.12%',
#   'Operating Margin': '-6.94%',
#   'Return on Assets': '-5.04%',
#   'Return on Equity': '-18.11%',
#   'Revenue': '165.62M',
#   'Revenue Per Share': '7.72',
#   'Quarterly Revenue Growth': '-24.80%',
#   'Gross Profit': '-524k',
#   'EBITDA': '-3.26M',
#   'Net Income Avi to Common': '-10.14M',
#   'Diluted EPS': '-0.4720',
#   'Quarterly Earnings Growth': 'N/A',
#   'Total Cash': '42.31M',
#   'Total Cash Per Share': '1.98',
#   'Total Debt': '25.21M',
#   'Total Debt/Equity': '49.85',
#   'Current Ratio': '2.89',
#   'Book Value Per Share': '2.36',
#   'Operating Cash Flow': '-121k',
#   'Levered Free Cash Flow': '-20.16M',
#   'Beta (5Y Monthly)': '0.48',
#   '52-Week Change': '-61.60%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '3.8300',
#   '52 Week Low': '1.2900',
#   '50-Day Moving Average': '1.4703',
#   '200-Day Moving Average': '1.5809',
#   'Avg Vol (3 month)': '32.94k',
#   'Avg Vol (10 day)': '14.03k',
#   'Shares Outstanding': '21.41M',
#   'Float': '18.34M',
#   '% Held by Insiders': '3.48%',
#   '% Held by Institutions': '69.22%',
#   'Shares Short (Sep 14, 2020)': '17.04k',
#   'Short Ratio (Sep 14, 2020)': '0.52',
#   'Short % of Float (Sep 14, 2020)': '0.09%',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '0.07%',
#   'Shares Short (prior month Aug 13, 2020)': '15.21k',
#   'Forward Annual Dividend Rate': '0.16',
#   'Forward Annual Dividend Yield': '11.51%',
#   'Trailing Annual Dividend Rate': '0.32',
#   'Trailing Annual Dividend Yield': '23.02%',
#   '5 Year Average Dividend Yield': '8.48',
#   'Payout Ratio': 'N/A',
#   'Dividend Date': 'Dec 03, 2020',
#   'Ex-Dividend Date': 'Nov 11, 2020',
#   'Last Split Factor': '10:1',
#   'Last Split Date': 'Feb 02, 2015'},
#  {'name': 'Arlington Asset Investment Corp. (AI)',
#   'Market Cap (intraday)': '92.44M',
#   'Enterprise Value': 'N/A',
#   'Trailing P/E': '18.77',
#   'Forward P/E': '22.94',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '7.25',
#   'Price/Book': '0.46',
#   'Enterprise Value/Revenue': 'N/A',
#   'Enterprise Value/EBITDA': 'N/A',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '0.00%',
#   'Operating Margin': '126.35%',
#   'Return on Assets': '-2.65%',
#   'Return on Equity': '-22.82%',
#   'Revenue': '-50.48M',
#   'Revenue Per Share': '-1.38',
#   'Quarterly Revenue Growth': 'N/A',
#   'Gross Profit': '28.76M',
#   'EBITDA': 'N/A',
#   'Net Income Avi to Common': '-67.34M',
#   'Diluted EPS': '-1.8380',
#   'Quarterly Earnings Growth': 'N/A',
#   'Total Cash': '596.04M',
#   'Total Cash Per Share': '17.02',
#   'Total Debt': '501.11M',
#   'Total Debt/Equity': '209.68',
#   'Current Ratio': '1.48',
#   'Book Value Per Share': '5.67',
#   'Operating Cash Flow': '43.84M',
#   'Levered Free Cash Flow': 'N/A',
#   'Beta (5Y Monthly)': '1.67',
#   '52-Week Change': '-47.12%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '6.7700',
#   '52 Week Low': '1.4000',
#   '50-Day Moving Average': '2.7468',
#   '200-Day Moving Average': '2.7215',
#   'Avg Vol (3 month)': '258.76k',
#   'Avg Vol (10 day)': '214.35k',
#   'Shares Outstanding': '35.02M',
#   'Float': '34.28M',
#   '% Held by Insiders': '2.12%',
#   '% Held by Institutions': '46.49%',
#   'Shares Short (Sep 14, 2020)': '978.78k',
#   'Short Ratio (Sep 14, 2020)': '4.4',
#   'Short % of Float (Sep 14, 2020)': '3.20%',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '2.80%',
#   'Shares Short (prior month Aug 13, 2020)': '885.62k',
#   'Forward Annual Dividend Rate': 'N/A',
#   'Forward Annual Dividend Yield': 'N/A',
#   'Trailing Annual Dividend Rate': '0.45',
#   'Trailing Annual Dividend Yield': '15.79%',
#   '5 Year Average Dividend Yield': '21.01',
#   'Payout Ratio': 'N/A',
#   'Dividend Date': 'Feb 02, 2020',
#   'Ex-Dividend Date': 'Dec 29, 2019',
#   'Last Split Factor': '1:20',
#   'Last Split Date': 'Oct 06, 2009'},
#  {'name': 'Apollo Tactical Income Fund Inc. (AIF)',
#   'Market Cap (intraday)': '184.42M',
#   'Enterprise Value': 'N/A',
#   'Trailing P/E': '7.27',
#   'Forward P/E': 'N/A',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '6.86',
#   'Price/Book': '0.88',
#   'Enterprise Value/Revenue': 'N/A',
#   'Enterprise Value/EBITDA': 'N/A',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '-64.38%',
#   'Operating Margin': '79.11%',
#   'Return on Assets': '3.26%',
#   'Return on Equity': '-7.07%',
#   'Revenue': '24.86M',
#   'Revenue Per Share': '1.72',
#   'Quarterly Revenue Growth': '-20.60%',
#   'Gross Profit': '27.78M',
#   'EBITDA': 'N/A',
#   'Net Income Avi to Common': '-16M',
#   'Diluted EPS': '-1.11',
#   'Quarterly Earnings Growth': 'N/A',
#   'Total Cash': '8.89M',
#   'Total Cash Per Share': '0.62',
#   'Total Debt': '109.79M',
#   'Total Debt/Equity': '52.30',
#   'Current Ratio': '0.28',
#   'Book Value Per Share': '14.51',
#   'Operating Cash Flow': '39.27M',
#   'Levered Free Cash Flow': '21.22M',
#   'Beta (5Y Monthly)': '0.60',
#   '52-Week Change': '-13.64%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '15.89',
#   '52 Week Low': '8.28',
#   '50-Day Moving Average': '12.75',
#   '200-Day Moving Average': '12.14',
#   'Avg Vol (3 month)': '60.78k',
#   'Avg Vol (10 day)': '47.93k',
#   'Shares Outstanding': '14.46M',
#   'Float': 'N/A',
#   '% Held by Insiders': '0.00%',
#   '% Held by Institutions': '37.95%',
#   'Shares Short (Sep 14, 2020)': '1.48k',
#   'Short Ratio (Sep 14, 2020)': '0.03',
#   'Short % of Float (Sep 14, 2020)': 'N/A',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '0.01%',
#   'Shares Short (prior month Aug 13, 2020)': '3.81k',
#   'Forward Annual Dividend Rate': '0.82',
#   'Forward Annual Dividend Yield': '6.41%',
#   'Trailing Annual Dividend Rate': '1.14',
#   'Trailing Annual Dividend Yield': '8.96%',
#   '5 Year Average Dividend Yield': '8.61',
#   'Payout Ratio': 'N/A',
#   'Dividend Date': 'Feb 19, 2019',
#   'Ex-Dividend Date': 'Sep 15, 2020',
#   'Last Split Factor': 'N/A',
#   'Last Split Date': 'N/A'},
#  {'name': 'AIM ImmunoTech Inc. (AIM)',
#   'Market Cap (intraday)': '80.57M',
#   'Enterprise Value': '48.65M',
#   'Trailing P/E': '2.82',
#   'Forward P/E': 'N/A',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '221.79',
#   'Price/Book': '1.74',
#   'Enterprise Value/Revenue': '248.22',
#   'Enterprise Value/EBITDA': '-4.93',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '0.00%',
#   'Operating Margin': '-6,562.25%',
#   'Return on Assets': '-25.15%',
#   'Return on Equity': '-42.21%',
#   'Revenue': '196k',
#   'Revenue Per Share': '0.01',
#   'Quarterly Revenue Growth': '37.90%',
#   'Gross Profit': '-753k',
#   'EBITDA': '-12.08M',
#   'Net Income Avi to Common': '-11.3M',
#   'Diluted EPS': '-5.8730',
#   'Quarterly Earnings Growth': 'N/A',
#   'Total Cash': '35M',
#   'Total Cash Per Share': '0.88',
#   'Total Debt': '2.34M',
#   'Total Debt/Equity': '4.99',
#   'Current Ratio': '42.22',
#   'Book Value Per Share': '2.14',
#   'Operating Cash Flow': '-9.36M',
#   'Levered Free Cash Flow': '-7.25M',
#   'Beta (5Y Monthly)': '-0.97',
#   '52-Week Change': '274.58%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '7.1100',
#   '52 Week Low': '0.3800',
#   '50-Day Moving Average': '2.1429',
#   '200-Day Moving Average': '2.4420',
#   'Avg Vol (3 month)': '5.65M',
#   'Avg Vol (10 day)': '906.48k',
#   'Shares Outstanding': '39.69M',
#   'Float': '39.25M',
#   '% Held by Insiders': '2.00%',
#   '% Held by Institutions': '2.10%',
#   'Shares Short (Sep 14, 2020)': '1.92M',
#   'Short Ratio (Sep 14, 2020)': '0.64',
#   'Short % of Float (Sep 14, 2020)': '4.89%',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '4.84%',
#   'Shares Short (prior month Aug 13, 2020)': '2.69M',
#   'Forward Annual Dividend Rate': 'N/A',
#   'Forward Annual Dividend Yield': 'N/A',
#   'Trailing Annual Dividend Rate': 'N/A',
#   'Trailing Annual Dividend Yield': 'N/A',
#   '5 Year Average Dividend Yield': 'N/A',
#   'Payout Ratio': '0.00%',
#   'Dividend Date': 'N/A',
#   'Ex-Dividend Date': 'N/A',
#   'Last Split Factor': '1:44',
#   'Last Split Date': 'Jun 10, 2019'},
#  {'name': 'Great Ajax Corp. (AJX)',
#   'Market Cap (intraday)': '210.91M',
#   'Enterprise Value': 'N/A',
#   'Trailing P/E': '9.68',
#   'Forward P/E': '8.73',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '6.35',
#   'Price/Book': '0.59',
#   'Enterprise Value/Revenue': '40.31',
#   'Enterprise Value/EBITDA': '16.82',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '44.40%',
#   'Operating Margin': '50.81%',
#   'Return on Assets': '1.62%',
#   'Return on Equity': '6.08%',
#   'Revenue': '51.42M',
#   'Revenue Per Share': '2.36',
#   'Quarterly Revenue Growth': '-23.00%',
#   'Gross Profit': '50.71M',
#   'EBITDA': 'N/A',
#   'Net Income Avi to Common': '20.84M',
#   'Diluted EPS': '0.96',
#   'Quarterly Earnings Growth': '-38.00%',
#   'Total Cash': '163.42M',
#   'Total Cash Per Share': '7.13',
#   'Total Debt': '1.13B',
#   'Total Debt/Equity': '227.06',
#   'Current Ratio': '3.06',
#   'Book Value Per Share': '15.61',
#   'Operating Cash Flow': '-15.71M',
#   'Levered Free Cash Flow': 'N/A',
#   'Beta (5Y Monthly)': '1.56',
#   '52-Week Change': '-43.45%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '15.96',
#   '52 Week Low': '3.96',
#   '50-Day Moving Average': '9.25',
#   '200-Day Moving Average': '8.45',
#   'Avg Vol (3 month)': '141.14k',
#   'Avg Vol (10 day)': '594.73k',
#   'Shares Outstanding': '22.93M',
#   'Float': '21.38M',
#   '% Held by Insiders': '8.09%',
#   '% Held by Institutions': '75.52%',
#   'Shares Short (Sep 14, 2020)': '440.47k',
#   'Short Ratio (Sep 14, 2020)': '5.54',
#   'Short % of Float (Sep 14, 2020)': '3.73%',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '1.92%',
#   'Shares Short (prior month Aug 13, 2020)': '359.82k',
#   'Forward Annual Dividend Rate': '0.68',
#   'Forward Annual Dividend Yield': '7.80%',
#   'Trailing Annual Dividend Rate': '1.10',
#   'Trailing Annual Dividend Yield': '12.58%',
#   '5 Year Average Dividend Yield': '8.71',
#   'Payout Ratio': '118.95%',
#   'Dividend Date': 'Aug 30, 2020',
#   'Ex-Dividend Date': 'Aug 12, 2020',
#   'Last Split Factor': 'N/A',
#   'Last Split Date': 'N/A'},
#  {'name': 'Akumin Inc. (AKU)',
#   'Market Cap (intraday)': '214.04M',
#   'Enterprise Value': '683.18M',
#   'Trailing P/E': '61.00',
#   'Forward P/E': '13.09',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '0.80',
#   'Price/Book': '1.55',
#   'Enterprise Value/Revenue': '2.52',
#   'Enterprise Value/EBITDA': '8.40',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '1.38%',
#   'Operating Margin': '18.49%',
#   'Return on Assets': '4.82%',
#   'Return on Equity': '4.38%',
#   'Revenue': '270.79M',
#   'Revenue Per Share': '3.88',
#   'Quarterly Revenue Growth': '-0.70%',
#   'Gross Profit': '142.45M',
#   'EBITDA': '69.46M',
#   'Net Income Avi to Common': '3.74M',
#   'Diluted EPS': 'N/A',
#   'Quarterly Earnings Growth': 'N/A',
#   'Total Cash': '28.08M',
#   'Total Cash Per Share': '0.4',
#   'Total Debt': '502.4M',
#   'Total Debt/Equity': '354.70',
#   'Current Ratio': '2.36',
#   'Book Value Per Share': 'N/A',
#   'Operating Cash Flow': '27.25M',
#   'Levered Free Cash Flow': '16.2M',
#   'Beta (5Y Monthly)': '1.90',
#   '52-Week Change': '8.33%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '3.4700',
#   '52 Week Low': '2.7000',
#   '50-Day Moving Average': '3.0462',
#   '200-Day Moving Average': '3.0462',
#   'Avg Vol (3 month)': '66.14k',
#   'Avg Vol (10 day)': '26.02k',
#   'Shares Outstanding': '70.18M',
#   'Float': '43.4M',
#   '% Held by Insiders': '22.30%',
#   '% Held by Institutions': '7.09%',
#   'Shares Short (Sep 14, 2020)': '6.04k',
#   'Short Ratio (Sep 14, 2020)': '0.25',
#   'Short % of Float (Sep 14, 2020)': 'N/A',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '0.01%',
#   'Shares Short (prior month )': 'N/A',
#   'Forward Annual Dividend Rate': 'N/A',
#   'Forward Annual Dividend Yield': 'N/A',
#   'Trailing Annual Dividend Rate': 'N/A',
#   'Trailing Annual Dividend Yield': 'N/A',
#   '5 Year Average Dividend Yield': 'N/A',
#   'Payout Ratio': '0.00%',
#   'Dividend Date': 'N/A',
#   'Ex-Dividend Date': 'N/A',
#   'Last Split Factor': 'N/A',
#   'Last Split Date': 'N/A'},
#  {'name': 'Albemarle Corporation (ALB)',
#   'Market Cap (intraday)': '9.50B',
#   'Enterprise Value': '12.32B',
#   'Trailing P/E': '21.67',
#   'Forward P/E': '20.45',
#   'PEG Ratio (5 yr expected)': '1.85',
#   'Price/Sales': '2.81',
#   'Price/Book': '2.36',
#   'Enterprise Value/Revenue': '3.65',
#   'Enterprise Value/EBITDA': '16.72',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '12.99%',
#   'Operating Margin': '19.61%',
#   'Return on Assets': '4.53%',
#   'Return on Equity': '12.35%',
#   'Revenue': '3.38B',
#   'Revenue Per Share': '31.80',
#   'Quarterly Revenue Growth': '-13.70%',
#   'Gross Profit': '1.26B',
#   'EBITDA': '884.66M',
#   'Net Income Avi to Common': '438.29M',
#   'Diluted EPS': '4.12',
#   'Quarterly Earnings Growth': '-44.50%',
#   'Total Cash': '736.7M',
#   'Total Cash Per Share': '6.93',
#   'Total Debt': '3.68B',
#   'Total Debt/Equity': '87.41',
#   'Current Ratio': '1.61',
#   'Book Value Per Share': '37.85',
#   'Operating Cash Flow': '728M',
#   'Levered Free Cash Flow': '-51.35M',
#   'Beta (5Y Monthly)': '1.41',
#   '52-Week Change': '35.95%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '101.00',
#   '52 Week Low': '48.89',
#   '50-Day Moving Average': '92.26',
#   '200-Day Moving Average': '77.08',
#   'Avg Vol (3 month)': '1.18M',
#   'Avg Vol (10 day)': '1.3M',
#   'Shares Outstanding': '106.36M',
#   'Float': '105.9M',
#   '% Held by Insiders': '0.51%',
#   '% Held by Institutions': '92.64%',
#   'Shares Short (Sep 14, 2020)': '9.27M',
#   'Short Ratio (Sep 14, 2020)': '11.15',
#   'Short % of Float (Sep 14, 2020)': '9.98%',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '8.72%',
#   'Shares Short (prior month Aug 13, 2020)': '10.53M',
#   'Forward Annual Dividend Rate': '1.54',
#   'Forward Annual Dividend Yield': '1.78%',
#   'Trailing Annual Dividend Rate': '1.50',
#   'Trailing Annual Dividend Yield': '1.69%',
#   '5 Year Average Dividend Yield': '1.61',
#   'Payout Ratio': '36.53%',
#   'Dividend Date': 'Sep 30, 2020',
#   'Ex-Dividend Date': 'Sep 16, 2020',
#   'Last Split Factor': '2:1',
#   'Last Split Date': 'Mar 01, 2007'},
#  {'name': 'Alcon Inc. (ALC)',
#   'Market Cap (intraday)': '27.82B',
#   'Enterprise Value': '31.00B',
#   'Trailing P/E': 'N/A',
#   'Forward P/E': '28.25',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '4.07',
#   'Price/Book': '1.48',
#   'Enterprise Value/Revenue': '4.53',
#   'Enterprise Value/EBITDA': '35.22',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '-9.30%',
#   'Operating Margin': '-4.17%',
#   'Return on Assets': '-0.64%',
#   'Return on Equity': '-3.33%',
#   'Revenue': '6.84B',
#   'Revenue Per Share': '13.99',
#   'Quarterly Revenue Growth': '-36.20%',
#   'Gross Profit': '3.66B',
#   'EBITDA': '1.14B',
#   'Net Income Avi to Common': '-636M',
#   'Diluted EPS': '-1.30',
#   'Quarterly Earnings Growth': 'N/A',
#   'Total Cash': '1.34B',
#   'Total Cash Per Share': '2.74',
#   'Total Debt': '4.5B',
#   'Total Debt/Equity': '24.00',
#   'Current Ratio': '2.23',
#   'Book Value Per Share': '38.39',
#   'Operating Cash Flow': '677M',
#   'Levered Free Cash Flow': '679.63M',
#   'Beta (5Y Monthly)': 'N/A',
#   '52-Week Change': '-0.28%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '65.37',
#   '52 Week Low': '39.37',
#   '50-Day Moving Average': '57.58',
#   '200-Day Moving Average': '56.99',
#   'Avg Vol (3 month)': '1.22M',
#   'Avg Vol (10 day)': '943.58k',
#   'Shares Outstanding': '489.1M',
#   'Float': '488.93M',
#   '% Held by Insiders': '0.00%',
#   '% Held by Institutions': '57.98%',
#   'Shares Short (Sep 14, 2020)': '5.62M',
#   'Short Ratio (Sep 14, 2020)': '3.76',
#   'Short % of Float (Sep 14, 2020)': 'N/A',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '1.15%',
#   'Shares Short (prior month Aug 13, 2020)': '6.96M',
#   'Forward Annual Dividend Rate': 'N/A',
#   'Forward Annual Dividend Yield': 'N/A',
#   'Trailing Annual Dividend Rate': '0.20',
#   'Trailing Annual Dividend Yield': '0.34%',
#   '5 Year Average Dividend Yield': 'N/A',
#   'Payout Ratio': '0.00%',
#   'Dividend Date': 'N/A',
#   'Ex-Dividend Date': 'N/A',
#   'Last Split Factor': 'N/A',
#   'Last Split Date': 'N/A'},
#  {'name': 'Alithya Group Inc. (ALYA)',
#   'Market Cap (intraday)': '122.73M',
#   'Enterprise Value': '163.13M',
#   'Trailing P/E': 'N/A',
#   'Forward P/E': '73.53',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '0.59',
#   'Price/Book': '1.36',
#   'Enterprise Value/Revenue': '0.59',
#   'Enterprise Value/EBITDA': '-5.98',
#   'Fiscal Year Ends': 'Mar 30, 2020',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '-15.37%',
#   'Operating Margin': '0.00%',
#   'Return on Assets': '-2.78%',
#   'Return on Equity': '-31.51%',
#   'Revenue': 'N/A',
#   'Revenue Per Share': 'N/A',
#   'Quarterly Revenue Growth': '-2.10%',
#   'Gross Profit': '82.97M',
#   'EBITDA': 'N/A',
#   'Net Income Avi to Common': 'N/A',
#   'Diluted EPS': '-0.2410',
#   'Quarterly Earnings Growth': 'N/A',
#   'Total Cash': 'N/A',
#   'Total Cash Per Share': 'N/A',
#   'Total Debt': 'N/A',
#   'Total Debt/Equity': '55.71',
#   'Current Ratio': '1.54',
#   'Book Value Per Share': '0.81',
#   'Operating Cash Flow': 'N/A',
#   'Levered Free Cash Flow': 'N/A',
#   'Beta (5Y Monthly)': 'N/A',
#   '52-Week Change': '-16.55%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '3.1700',
#   '52 Week Low': '0.9600',
#   '50-Day Moving Average': '2.0485',
#   '200-Day Moving Average': '1.7883',
#   'Avg Vol (3 month)': '18.1k',
#   'Avg Vol (10 day)': '16.03k',
#   'Shares Outstanding': '50.91M',
#   'Float': '40.59M',
#   '% Held by Insiders': '27.98%',
#   '% Held by Institutions': '40.46%',
#   'Shares Short (Sep 14, 2020)': '17.81k',
#   'Short Ratio (Sep 14, 2020)': '0.83',
#   'Short % of Float (Sep 14, 2020)': '0.05%',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '0.03%',
#   'Shares Short (prior month Aug 13, 2020)': '1.87k',
#   'Forward Annual Dividend Rate': 'N/A',
#   'Forward Annual Dividend Yield': 'N/A',
#   'Trailing Annual Dividend Rate': 'N/A',
#   'Trailing Annual Dividend Yield': 'N/A',
#   '5 Year Average Dividend Yield': 'N/A',
#   'Payout Ratio': '0.00%',
#   'Dividend Date': 'N/A',
#   'Ex-Dividend Date': 'N/A',
#   'Last Split Factor': 'N/A',
#   'Last Split Date': 'N/A'},
#  {'name': 'Aphria Inc. (APHA)',
#   'Market Cap (intraday)': '1.21B',
#   'Enterprise Value': '1.15B',
#   'Trailing P/E': '57.50',
#   'Forward P/E': '1.00k',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '2.67',
#   'Price/Book': '0.89',
#   'Enterprise Value/Revenue': '2.12',
#   'Enterprise Value/EBITDA': '392.34',
#   'Fiscal Year Ends': 'May 30, 2020',
#   'Most Recent Quarter': 'May 30, 2020',
#   'Profit Margin': '-15.60%',
#   'Operating Margin': '0.00%',
#   'Return on Assets': '0.07%',
#   'Return on Equity': '-4.74%',
#   'Revenue': 'N/A',
#   'Revenue Per Share': 'N/A',
#   'Quarterly Revenue Growth': '18.40%',
#   'Gross Profit': '190.97M',
#   'EBITDA': 'N/A',
#   'Net Income Avi to Common': 'N/A',
#   'Diluted EPS': '0.2990',
#   'Quarterly Earnings Growth': 'N/A',
#   'Total Cash': 'N/A',
#   'Total Cash Per Share': 'N/A',
#   'Total Debt': 'N/A',
#   'Total Debt/Equity': '22.66',
#   'Current Ratio': '5.30',
#   'Book Value Per Share': '5.34',
#   'Operating Cash Flow': 'N/A',
#   'Levered Free Cash Flow': 'N/A',
#   'Beta (5Y Monthly)': '2.09',
#   '52-Week Change': '-18.18%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '6.1500',
#   '52 Week Low': '1.9500',
#   '50-Day Moving Average': '4.5488',
#   '200-Day Moving Average': '4.1687',
#   'Avg Vol (3 month)': '5.15M',
#   'Avg Vol (10 day)': '2.14M',
#   'Shares Outstanding': '267.59M',
#   'Float': '287.65M',
#   '% Held by Insiders': '2.84%',
#   '% Held by Institutions': '14.42%',
#   'Shares Short (Sep 14, 2020)': '35.14M',
#   'Short Ratio (Sep 14, 2020)': '11.16',
#   'Short % of Float (Sep 14, 2020)': 'N/A',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '12.19%',
#   'Shares Short (prior month Aug 13, 2020)': '40.94M',
#   'Forward Annual Dividend Rate': 'N/A',
#   'Forward Annual Dividend Yield': 'N/A',
#   'Trailing Annual Dividend Rate': 'N/A',
#   'Trailing Annual Dividend Yield': 'N/A',
#   '5 Year Average Dividend Yield': 'N/A',
#   'Payout Ratio': '0.00%',
#   'Dividend Date': 'N/A',
#   'Ex-Dividend Date': 'N/A',
#   'Last Split Factor': 'N/A',
#   'Last Split Date': 'N/A'},
#  {'name': 'ChampionX Corporation (APY)',
#   'Market Cap (intraday)': '1.64B',
#   'Enterprise Value': '2.72B',
#   'Trailing P/E': '25.70',
#   'Forward P/E': '72.46',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '0.66',
#   'Price/Book': '1.02',
#   'Enterprise Value/Revenue': '2.51',
#   'Enterprise Value/EBITDA': '-4.66',
#   'Fiscal Year Ends': 'N/A',
#   'Most Recent Quarter': 'N/A',
#   'Profit Margin': 'N/A',
#   'Operating Margin': 'N/A',
#   'Return on Assets': 'N/A',
#   'Return on Equity': 'N/A',
#   'Revenue': 'N/A',
#   'Revenue Per Share': 'N/A',
#   'Quarterly Revenue Growth': 'N/A',
#   'Gross Profit': '380.7M',
#   'EBITDA': 'N/A',
#   'Net Income Avi to Common': 'N/A',
#   'Diluted EPS': 'N/A',
#   'Quarterly Earnings Growth': 'N/A',
#   'Total Cash': 'N/A',
#   'Total Cash Per Share': 'N/A',
#   'Total Debt': 'N/A',
#   'Total Debt/Equity': 'N/A',
#   'Current Ratio': 'N/A',
#   'Book Value Per Share': 'N/A',
#   'Operating Cash Flow': 'N/A',
#   'Levered Free Cash Flow': 'N/A',
#   'Beta (5Y Monthly)': 'N/A',
#   '52-Week Change': 'N/A',
#   'S&P500 52-Week Change': 'N/A',
#   '52 Week High': '34.80',
#   '52 Week Low': '2.89',
#   '50-Day Moving Average': '9.45',
#   '200-Day Moving Average': '9.10',
#   'Avg Vol (3 month)': '2.07M',
#   'Avg Vol (10 day)': '2M',
#   'Shares Outstanding': 'N/A',
#   'Float': 'N/A',
#   '% Held by Insiders': 'N/A',
#   '% Held by Institutions': 'N/A',
#   'Shares Short ': 'N/A',
#   'Short Ratio ': 'N/A',
#   'Short % of Float ': 'N/A',
#   'Short % of Shares Outstanding ': 'N/A',
#   'Shares Short (prior month )': 'N/A',
#   'Forward Annual Dividend Rate': 'N/A',
#   'Forward Annual Dividend Yield': 'N/A',
#   'Trailing Annual Dividend Rate': 'N/A',
#   'Trailing Annual Dividend Yield': 'N/A',
#   '5 Year Average Dividend Yield': 'N/A',
#   'Payout Ratio': 'N/A',
#   'Dividend Date': 'N/A',
#   'Ex-Dividend Date': 'N/A',
#   'Last Split Factor': 'N/A',
#   'Last Split Date': 'N/A'},
#  {'name': 'Algonquin Power & Utilities Corp. (AQN)',
#   'Market Cap (intraday)': '8.26B',
#   'Enterprise Value': '12.54B',
#   'Trailing P/E': '14.42',
#   'Forward P/E': '19.08',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '4.54',
#   'Price/Book': '2.15',
#   'Enterprise Value/Revenue': '7.78',
#   'Enterprise Value/EBITDA': '12.46',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '31.64%',
#   'Operating Margin': '20.92%',
#   'Return on Assets': '1.99%',
#   'Return on Equity': '10.04%',
#   'Revenue': '1.61B',
#   'Revenue Per Share': '3.11',
#   'Quarterly Revenue Growth': '0.00%',
#   'Gross Profit': '709.63M',
#   'EBITDA': '635.35M',
#   'Net Income Avi to Common': '501.85M',
#   'Diluted EPS': '0.96',
#   'Quarterly Earnings Growth': '82.70%',
#   'Total Cash': '60.31M',
#   'Total Cash Per Share': '0.1',
#   'Total Debt': '4.29B',
#   'Total Debt/Equity': '88.28',
#   'Current Ratio': '0.62',
#   'Book Value Per Share': '7.19',
#   'Operating Cash Flow': '565.35M',
#   'Levered Free Cash Flow': '-270.37M',
#   'Beta (5Y Monthly)': '0.34',
#   '52-Week Change': '4.98%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '16.85',
#   '52 Week Low': '9.53',
#   '50-Day Moving Average': '14.03',
#   '200-Day Moving Average': '13.60',
#   'Avg Vol (3 month)': '791.96k',
#   'Avg Vol (10 day)': '823.82k',
#   'Shares Outstanding': '592.27M',
#   'Float': '591.67M',
#   '% Held by Insiders': '0.31%',
#   '% Held by Institutions': '49.41%',
#   'Shares Short (Sep 14, 2020)': '4.14M',
#   'Short Ratio (Sep 14, 2020)': '6.55',
#   'Short % of Float (Sep 14, 2020)': 'N/A',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '0.70%',
#   'Shares Short (prior month Aug 13, 2020)': '4.2M',
#   'Forward Annual Dividend Rate': '0.62',
#   'Forward Annual Dividend Yield': '4.23%',
#   'Trailing Annual Dividend Rate': '0.58',
#   'Trailing Annual Dividend Yield': '3.92%',
#   '5 Year Average Dividend Yield': '4.42',
#   'Payout Ratio': '59.60%',
#   'Dividend Date': 'Oct 14, 2020',
#   'Ex-Dividend Date': 'Sep 28, 2020',
#   'Last Split Factor': 'N/A',
#   'Last Split Date': 'N/A'},
#  {'name': 'Antero Resources Corporation (AR)',
#   'Market Cap (intraday)': '738.51M',
#   'Enterprise Value': '6.82B',
#   'Trailing P/E': 'N/A',
#   'Forward P/E': '5.53',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '0.26',
#   'Price/Book': '0.12',
#   'Enterprise Value/Revenue': '2.26',
#   'Enterprise Value/EBITDA': '-3.92',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '-66.30%',
#   'Operating Margin': '-42.08%',
#   'Return on Assets': '-5.52%',
#   'Return on Equity': '-29.28%',
#   'Revenue': '3.26B',
#   'Revenue Per Share': '11.25',
#   'Quarterly Revenue Growth': '-32.80%',
#   'Gross Profit': '1.82B',
#   'EBITDA': '692.04M',
#   'Net Income Avi to Common': '-2.16B',
#   'Diluted EPS': '-7.4560',
#   'Quarterly Earnings Growth': 'N/A',
#   'Total Cash': 'N/A',
#   'Total Cash Per Share': 'N/A',
#   'Total Debt': '6.08B',
#   'Total Debt/Equity': '94.56',
#   'Current Ratio': '0.98',
#   'Book Value Per Share': '22.86',
#   'Operating Cash Flow': '662.99M',
#   'Levered Free Cash Flow': '-389.04M',
#   'Beta (5Y Monthly)': '4.76',
#   '52-Week Change': '4.49%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '4.6400',
#   '52 Week Low': '0.6400',
#   '50-Day Moving Average': '3.1382',
#   '200-Day Moving Average': '2.7614',
#   'Avg Vol (3 month)': '11.42M',
#   'Avg Vol (10 day)': '8.73M',
#   'Shares Outstanding': '268.55M',
#   'Float': '224.66M',
#   '% Held by Insiders': '12.53%',
#   '% Held by Institutions': '107.41%',
#   'Shares Short (Sep 14, 2020)': '52.3M',
#   'Short Ratio (Sep 14, 2020)': '3.63',
#   'Short % of Float (Sep 14, 2020)': '25.47%',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '19.47%',
#   'Shares Short (prior month Aug 13, 2020)': '40.56M',
#   'Forward Annual Dividend Rate': 'N/A',
#   'Forward Annual Dividend Yield': 'N/A',
#   'Trailing Annual Dividend Rate': 'N/A',
#   'Trailing Annual Dividend Yield': 'N/A',
#   '5 Year Average Dividend Yield': 'N/A',
#   'Payout Ratio': '0.00%',
#   'Dividend Date': 'N/A',
#   'Ex-Dividend Date': 'N/A',
#   'Last Split Factor': 'N/A',
#   'Last Split Date': 'N/A'},
#  {'name': 'Alexandria Real Estate Equities, Inc. (ARE)',
#   'Market Cap (intraday)': '19.75B',
#   'Enterprise Value': '27.06B',
#   'Trailing P/E': '47.31',
#   'Forward P/E': 'N/A',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '11.07',
#   'Price/Book': '2.09',
#   'Enterprise Value/Revenue': '16.15',
#   'Enterprise Value/EBITDA': '21.54',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '23.86%',
#   'Operating Margin': '27.15%',
#   'Return on Assets': '1.59%',
#   'Return on Equity': '4.66%',
#   'Revenue': '1.69B',
#   'Revenue Per Share': '14.33',
#   'Quarterly Revenue Growth': '17.50%',
#   'Gross Profit': '1.1B',
#   'EBITDA': '1.03B',
#   'Net Income Avi to Common': '395.66M',
#   'Diluted EPS': '3.34',
#   'Quarterly Earnings Growth': '191.60%',
#   'Total Cash': '206.86M',
#   'Total Cash Per Share': '1.64',
#   'Total Debt': '7.81B',
#   'Total Debt/Equity': '70.60',
#   'Current Ratio': '2.65',
#   'Book Value Per Share': '75.72',
#   'Operating Cash Flow': '769.17M',
#   'Levered Free Cash Flow': '815.02M',
#   'Beta (5Y Monthly)': '0.78',
#   '52-Week Change': '6.71%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '177.70',
#   '52 Week Low': '109.22',
#   '50-Day Moving Average': '164.92',
#   '200-Day Moving Average': '158.29',
#   'Avg Vol (3 month)': '813.44k',
#   'Avg Vol (10 day)': '1.05M',
#   'Shares Outstanding': '126.11M',
#   'Float': '124.58M',
#   '% Held by Insiders': '1.31%',
#   '% Held by Institutions': '100.43%',
#   'Shares Short (Sep 14, 2020)': '7.17M',
#   'Short Ratio (Sep 14, 2020)': '11.9',
#   'Short % of Float (Sep 14, 2020)': '6.78%',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '5.68%',
#   'Shares Short (prior month Aug 13, 2020)': '7.02M',
#   'Forward Annual Dividend Rate': '4.24',
#   'Forward Annual Dividend Yield': '2.60%',
#   'Trailing Annual Dividend Rate': '4.12',
#   'Trailing Annual Dividend Yield': '2.50%',
#   '5 Year Average Dividend Yield': '2.84',
#   'Payout Ratio': '124.47%',
#   'Dividend Date': 'Oct 14, 2020',
#   'Ex-Dividend Date': 'Sep 28, 2020',
#   'Last Split Factor': '1:1',
#   'Last Split Date': 'Apr 23, 2006'},
#  {'name': 'Avino Silver & Gold Mines Ltd. (ASM)',
#   'Market Cap (intraday)': '87.31M',
#   'Enterprise Value': '81.99M',
#   'Trailing P/E': 'N/A',
#   'Forward P/E': 'N/A',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '2.60',
#   'Price/Book': '1.55',
#   'Enterprise Value/Revenue': '2.81',
#   'Enterprise Value/EBITDA': '-3.56k',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '-110.33%',
#   'Operating Margin': '-10.54%',
#   'Return on Assets': '-2.12%',
#   'Return on Equity': '-4.51%',
#   'Revenue': '29.18M',
#   'Revenue Per Share': '0.38',
#   'Quarterly Revenue Growth': '-38.10%',
#   'Gross Profit': '-270k',
#   'EBITDA': '369k',
#   'Net Income Avi to Common': '-3.01M',
#   'Diluted EPS': '-0.4210',
#   'Quarterly Earnings Growth': 'N/A',
#   'Total Cash': '10.39M',
#   'Total Cash Per Share': '0.12',
#   'Total Debt': '5.07M',
#   'Total Debt/Equity': '9.07',
#   'Current Ratio': '2.92',
#   'Book Value Per Share': '0.67',
#   'Operating Cash Flow': '1.67M',
#   'Levered Free Cash Flow': '-526.75k',
#   'Beta (5Y Monthly)': '1.21',
#   '52-Week Change': '68.42%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '1.4900',
#   '52 Week Low': '0.2600',
#   '50-Day Moving Average': '1.1121',
#   '200-Day Moving Average': '0.7707',
#   'Avg Vol (3 month)': '2.13M',
#   'Avg Vol (10 day)': '661.78k',
#   'Shares Outstanding': '87.21M',
#   'Float': '83.52M',
#   '% Held by Insiders': '3.77%',
#   '% Held by Institutions': '7.95%',
#   'Shares Short (Sep 14, 2020)': '774.42k',
#   'Short Ratio (Sep 14, 2020)': '0.49',
#   'Short % of Float (Sep 14, 2020)': '0.92%',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '0.89%',
#   'Shares Short (prior month Aug 13, 2020)': '1.02M',
#   'Forward Annual Dividend Rate': 'N/A',
#   'Forward Annual Dividend Yield': 'N/A',
#   'Trailing Annual Dividend Rate': 'N/A',
#   'Trailing Annual Dividend Yield': 'N/A',
#   '5 Year Average Dividend Yield': 'N/A',
#   'Payout Ratio': '0.00%',
#   'Dividend Date': 'N/A',
#   'Ex-Dividend Date': 'N/A',
#   'Last Split Factor': 'N/A',
#   'Last Split Date': 'N/A'},
#  {'name': 'Ascendis Pharma A/S (ASND)',
#   'Market Cap (intraday)': '7.93B',
#   'Enterprise Value': '7.43B',
#   'Trailing P/E': 'N/A',
#   'Forward P/E': 'N/A',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '725.98',
#   'Price/Book': '14.20',
#   'Enterprise Value/Revenue': '882.87',
#   'Enterprise Value/EBITDA': '-28.62',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '0.00%',
#   'Operating Margin': '0.00%',
#   'Return on Assets': '-25.89%',
#   'Return on Equity': '-45.78%',
#   'Revenue': 'N/A',
#   'Revenue Per Share': 'N/A',
#   'Quarterly Revenue Growth': '-55.30%',
#   'Gross Profit': '13.38M',
#   'EBITDA': 'N/A',
#   'Net Income Avi to Common': 'N/A',
#   'Diluted EPS': '-3.87',
#   'Quarterly Earnings Growth': 'N/A',
#   'Total Cash': 'N/A',
#   'Total Cash Per Share': 'N/A',
#   'Total Debt': 'N/A',
#   'Total Debt/Equity': '7.44',
#   'Current Ratio': '9.04',
#   'Book Value Per Share': '8.43',
#   'Operating Cash Flow': 'N/A',
#   'Levered Free Cash Flow': 'N/A',
#   'Beta (5Y Monthly)': '0.82',
#   '52-Week Change': '68.04%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '161.95',
#   '52 Week Low': '90.06',
#   '50-Day Moving Average': '145.46',
#   '200-Day Moving Average': '138.75',
#   'Avg Vol (3 month)': '206.79k',
#   'Avg Vol (10 day)': '254.23k',
#   'Shares Outstanding': '53.17M',
#   'Float': '39.4M',
#   '% Held by Insiders': '1.36%',
#   '% Held by Institutions': '100.64%',
#   'Shares Short (Sep 14, 2020)': '2.05M',
#   'Short Ratio (Sep 14, 2020)': '13.34',
#   'Short % of Float (Sep 14, 2020)': 'N/A',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '3.86%',
#   'Shares Short (prior month Aug 13, 2020)': '1.91M',
#   'Forward Annual Dividend Rate': 'N/A',
#   'Forward Annual Dividend Yield': 'N/A',
#   'Trailing Annual Dividend Rate': 'N/A',
#   'Trailing Annual Dividend Yield': 'N/A',
#   '5 Year Average Dividend Yield': 'N/A',
#   'Payout Ratio': '0.00%',
#   'Dividend Date': 'N/A',
#   'Ex-Dividend Date': 'N/A',
#   'Last Split Factor': 'N/A',
#   'Last Split Date': 'N/A'},
#  {'name': 'Grupo Aeroportuario del Sureste, S. A. B. de C. V. (ASR)',
#   'Market Cap (intraday)': '3.44B',
#   'Enterprise Value': '3.83B',
#   'Trailing P/E': '13.51',
#   'Forward P/E': '24.45',
#   'PEG Ratio (5 yr expected)': '18.25',
#   'Price/Sales': '4.39',
#   'Price/Book': '2.15',
#   'Enterprise Value/Revenue': '0.23',
#   'Enterprise Value/EBITDA': '0.37',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '27.00%',
#   'Operating Margin': '0.00%',
#   'Return on Assets': '5.89%',
#   'Return on Equity': '10.18%',
#   'Revenue': 'N/A',
#   'Revenue Per Share': 'N/A',
#   'Quarterly Revenue Growth': '-56.60%',
#   'Gross Profit': '8.53B',
#   'EBITDA': 'N/A',
#   'Net Income Avi to Common': 'N/A',
#   'Diluted EPS': '9.69',
#   'Quarterly Earnings Growth': 'N/A',
#   'Total Cash': 'N/A',
#   'Total Cash Per Share': 'N/A',
#   'Total Debt': 'N/A',
#   'Total Debt/Equity': '36.24',
#   'Current Ratio': '3.88',
#   'Book Value Per Share': '45.84',
#   'Operating Cash Flow': 'N/A',
#   'Levered Free Cash Flow': 'N/A',
#   'Beta (5Y Monthly)': '0.63',
#   '52-Week Change': '-27.10%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '210.38',
#   '52 Week Low': '82.08',
#   '50-Day Moving Average': '112.86',
#   '200-Day Moving Average': '106.61',
#   'Avg Vol (3 month)': '68.11k',
#   'Avg Vol (10 day)': '48.53k',
#   'Shares Outstanding': '30M',
#   'Float': '16.59M',
#   '% Held by Insiders': '13.32%',
#   '% Held by Institutions': '24.56%',
#   'Shares Short (Sep 14, 2020)': '115.97k',
#   'Short Ratio (Sep 14, 2020)': '1.87',
#   'Short % of Float (Sep 14, 2020)': 'N/A',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '0.39%',
#   'Shares Short (prior month Aug 13, 2020)': '104.22k',
#   'Forward Annual Dividend Rate': 'N/A',
#   'Forward Annual Dividend Yield': 'N/A',
#   'Trailing Annual Dividend Rate': '0.34',
#   'Trailing Annual Dividend Yield': '0.30%',
#   '5 Year Average Dividend Yield': 'N/A',
#   'Payout Ratio': '0.00%',
#   'Dividend Date': 'Jun 16, 2019',
#   'Ex-Dividend Date': 'Jun 03, 2019',
#   'Last Split Factor': 'N/A',
#   'Last Split Date': 'N/A'},
#  {'name': 'Atlantic Power Corporation (AT)',
#   'Market Cap (intraday)': '175.95M',
#   'Enterprise Value': '727.65M',
#   'Trailing P/E': '9.32',
#   'Forward P/E': '9.94',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '0.77',
#   'Price/Book': '32.26',
#   'Enterprise Value/Revenue': '2.67',
#   'Enterprise Value/EBITDA': '8.28',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '-10.61%',
#   'Operating Margin': '13.00%',
#   'Return on Assets': '2.40%',
#   'Return on Equity': '-19.49%',
#   'Revenue': '272.3M',
#   'Revenue Per Share': '2.57',
#   'Quarterly Revenue Growth': '-12.60%',
#   'Gross Profit': '132.3M',
#   'EBITDA': '98.3M',
#   'Net Income Avi to Common': '-28.9M',
#   'Diluted EPS': '-0.2760',
#   'Quarterly Earnings Growth': 'N/A',
#   'Total Cash': '38M',
#   'Total Cash Per Share': '0.41',
#   'Total Debt': '600.2M',
#   'Total Debt/Equity': '567.83',
# ...
#   'Revenue': '4.53B',
#   'Revenue Per Share': '39.49',
#   'Quarterly Revenue Growth': '12.40%',
#   'Gross Profit': '1.26B',
#   'EBITDA': '924.2M',
#   'Net Income Avi to Common': '462.5M',
#   'Diluted EPS': '3.95',
#   'Quarterly Earnings Growth': '25.30%',
#   'Total Cash': '477.1M',
#   'Total Cash Per Share': '4.14',
#   'Total Debt': '2.11B',
#   'Total Debt/Equity': '156.78',
#   'Current Ratio': '0.99',
#   'Book Value Per Share': '11.70',
#   'Operating Cash Flow': '598.2M',
#   'Levered Free Cash Flow': '633.9M',
#   'Beta (5Y Monthly)': '0.87',
#   '52-Week Change': '9.54%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '144.50',
#   '52 Week Low': '81.90',
#   '50-Day Moving Average': '135.21',
#   '200-Day Moving Average': '122.87',
#   'Avg Vol (3 month)': '499.13k',
#   'Avg Vol (10 day)': '529.3k',
#   'Shares Outstanding': '114.82M',
#   'Float': '114.5M',
#   '% Held by Insiders': '0.66%',
#   '% Held by Institutions': '88.37%',
#   'Shares Short (Sep 14, 2020)': '1.64M',
#   'Short Ratio (Sep 14, 2020)': '3.73',
#   'Short % of Float (Sep 14, 2020)': '1.64%',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '1.42%',
#   'Shares Short (prior month Aug 13, 2020)': '1.84M',
#   'Forward Annual Dividend Rate': '2.3',
#   'Forward Annual Dividend Yield': '1.72%',
#   'Trailing Annual Dividend Rate': '2.16',
#   'Trailing Annual Dividend Yield': '1.62%',
#   '5 Year Average Dividend Yield': '1.68',
#   'Payout Ratio': '54.68%',
#   'Dividend Date': 'Oct 04, 2020',
#   'Ex-Dividend Date': 'Sep 13, 2020',
#   'Last Split Factor': 'N/A',
#   'Last Split Date': 'N/A'},
#  {'name': 'CF Industries Holdings, Inc. (CF)',
#   'Market Cap (intraday)': '6.56B',
#   'Enterprise Value': '10.24B',
#   'Trailing P/E': '17.44',
#   'Forward P/E': '18.05',
#   'PEG Ratio (5 yr expected)': '1.20',
#   'Price/Sales': '1.57',
#   'Price/Book': '2.28',
#   'Enterprise Value/Revenue': '2.40',
#   'Enterprise Value/EBITDA': '6.08',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '8.87%',
#   'Operating Margin': '18.37%',
#   'Return on Assets': '3.95%',
#   'Return on Equity': '9.08%',
#   'Revenue': '4.26B',
#   'Revenue Per Share': '19.67',
#   'Quarterly Revenue Growth': '-19.80%',
#   'Gross Profit': '1.17B',
#   'EBITDA': '1.67B',
#   'Net Income Avi to Common': '378M',
#   'Diluted EPS': '1.74',
#   'Quarterly Earnings Growth': '-32.90%',
#   'Total Cash': '563M',
#   'Total Cash Per Share': '2.63',
#   'Total Debt': '4.24B',
#   'Total Debt/Equity': '76.08',
#   'Current Ratio': '1.85',
#   'Book Value Per Share': '13.43',
#   'Operating Cash Flow': '1.53B',
#   'Levered Free Cash Flow': '1.02B',
#   'Beta (5Y Monthly)': '1.10',
#   '52-Week Change': 'N/A',
#   'S&P500 52-Week Change': 'N/A',
#   '52 Week High': '51.06',
#   '52 Week Low': '19.73',
#   '50-Day Moving Average': '32.55',
#   '200-Day Moving Average': '29.86',
#   'Avg Vol (3 month)': '2.39M',
#   'Avg Vol (10 day)': '1.82M',
#   'Shares Outstanding': '213.88M',
#   'Float': '212.59M',
#   '% Held by Insiders': '0.47%',
#   '% Held by Institutions': '97.41%',
#   'Shares Short (Sep 14, 2020)': '6.11M',
#   'Short Ratio (Sep 14, 2020)': '3.23',
#   'Short % of Float (Sep 14, 2020)': '3.76%',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '2.86%',
#   'Shares Short (prior month Aug 13, 2020)': '5.54M',
#   'Forward Annual Dividend Rate': '1.2',
#   'Forward Annual Dividend Yield': '3.93%',
#   'Trailing Annual Dividend Rate': '1.20',
#   'Trailing Annual Dividend Yield': '3.93%',
#   '5 Year Average Dividend Yield': '3.41',
#   'Payout Ratio': '68.18%',
#   'Dividend Date': 'Aug 30, 2020',
#   'Ex-Dividend Date': 'Aug 13, 2020',
#   'Last Split Factor': '5:1',
#   'Last Split Date': 'Jun 17, 2015'},
#  {'name': 'MFS Intermediate High Income Fund (CIF)',
#   'Market Cap (intraday)': '44.49M',
#   'Enterprise Value': 'N/A',
#   'Trailing P/E': '38.50',
#   'Forward P/E': 'N/A',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '40.68',
#   'Price/Book': '0.98',
#   'Enterprise Value/Revenue': 'N/A',
#   'Enterprise Value/EBITDA': 'N/A',
#   'Fiscal Year Ends': 'Nov 29, 2019',
#   'Most Recent Quarter': 'May 30, 2020',
#   'Profit Margin': '27.07%',
#   'Operating Margin': '82.55%',
#   'Return on Assets': '2.87%',
#   'Return on Equity': '2.15%',
#   'Revenue': '3.75M',
#   'Revenue Per Share': '0.19',
#   'Quarterly Revenue Growth': '-9.50%',
#   'Gross Profit': '3.94M',
#   'EBITDA': 'N/A',
#   'Net Income Avi to Common': '1.02M',
#   'Diluted EPS': '0.0520',
#   'Quarterly Earnings Growth': 'N/A',
#   'Total Cash': '1.39k',
#   'Total Cash Per Share': '0',
#   'Total Debt': '18.5M',
#   'Total Debt/Equity': '40.86',
#   'Current Ratio': '0.06',
#   'Book Value Per Share': '2.33',
#   'Operating Cash Flow': '6.4M',
#   'Levered Free Cash Flow': '2.12M',
#   'Beta (5Y Monthly)': '0.75',
#   '52-Week Change': '-7.11%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '3.0900',
#   '52 Week Low': '1.4100',
#   '50-Day Moving Average': '2.3262',
#   '200-Day Moving Average': '2.1851',
#   'Avg Vol (3 month)': '68.56k',
#   'Avg Vol (10 day)': '87.63k',
#   'Shares Outstanding': '19.26M',
#   'Float': 'N/A',
#   '% Held by Insiders': '0.00%',
#   '% Held by Institutions': '16.64%',
#   'Shares Short (Sep 14, 2020)': '99.69k',
#   'Short Ratio (Sep 14, 2020)': '1.31',
#   'Short % of Float (Sep 14, 2020)': 'N/A',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '0.52%',
#   'Shares Short (prior month Aug 13, 2020)': '20.97k',
#   'Forward Annual Dividend Rate': '0.23',
#   'Forward Annual Dividend Yield': '9.75%',
#   'Trailing Annual Dividend Rate': '0.24',
#   'Trailing Annual Dividend Yield': '10.13%',
#   '5 Year Average Dividend Yield': '10.04',
#   'Payout Ratio': '393.27%',
#   'Dividend Date': 'Feb 27, 2019',
#   'Ex-Dividend Date': 'Oct 12, 2020',
#   'Last Split Factor': 'N/A',
#   'Last Split Date': 'N/A'},
#  {'name': 'Colliers International Group Inc. (CIGI)',
#   'Market Cap (intraday)': '2.52B',
#   'Enterprise Value': '3.55B',
#   'Trailing P/E': '35.19',
#   'Forward P/E': '12.30',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '0.89',
#   'Price/Book': '5.12',
#   'Enterprise Value/Revenue': '1.25',
#   'Enterprise Value/EBITDA': '12.58',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '2.53%',
#   'Operating Margin': '7.23%',
#   'Return on Assets': '4.87%',
#   'Return on Equity': '13.34%',
#   'Revenue': '2.85B',
#   'Revenue Per Share': '71.52',
#   'Quarterly Revenue Growth': '-26.20%',
#   'Gross Profit': '1.09B',
#   'EBITDA': '304.88M',
#   'Net Income Avi to Common': '71.93M',
#   'Diluted EPS': '1.80',
#   'Quarterly Earnings Growth': 'N/A',
#   'Total Cash': '147.17M',
#   'Total Cash Per Share': '3.68',
#   'Total Debt': '1.17B',
#   'Total Debt/Equity': '134.32',
#   'Current Ratio': '0.99',
#   'Book Value Per Share': '12.38',
#   'Operating Cash Flow': '181M',
#   'Levered Free Cash Flow': '118.27M',
#   'Beta (5Y Monthly)': '1.60',
#   '52-Week Change': '-7.83%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '92.07',
#   '52 Week Low': '33.93',
#   '50-Day Moving Average': '64.96',
#   '200-Day Moving Average': '56.57',
#   'Avg Vol (3 month)': '83.11k',
#   'Avg Vol (10 day)': '148.9k',
#   'Shares Outstanding': '38.67M',
#   'Float': '28.43M',
#   '% Held by Insiders': '4.82%',
#   '% Held by Institutions': '73.79%',
#   'Shares Short (Sep 14, 2020)': '373.82k',
#   'Short Ratio (Sep 14, 2020)': '4.93',
#   'Short % of Float (Sep 14, 2020)': 'N/A',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '0.93%',
#   'Shares Short (prior month Aug 13, 2020)': '345.18k',
#   'Forward Annual Dividend Rate': '0.1',
#   'Forward Annual Dividend Yield': '0.15%',
#   'Trailing Annual Dividend Rate': '0.10',
#   'Trailing Annual Dividend Yield': '0.15%',
#   '5 Year Average Dividend Yield': '0.19',
#   'Payout Ratio': '5.56%',
#   'Dividend Date': 'Jul 12, 2020',
#   'Ex-Dividend Date': 'Jun 28, 2020',
#   'Last Split Factor': '1709:1000',
#   'Last Split Date': 'Jun 01, 2015'},
#  {'name': 'Cincinnati Financial Corporation (CINF)',
#   'Market Cap (intraday)': '12.27B',
#   'Enterprise Value': '12.54B',
#   'Trailing P/E': '22.92',
#   'Forward P/E': '19.68',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '1.93',
#   'Price/Book': '1.33',
#   'Enterprise Value/Revenue': '1.94',
#   'Enterprise Value/EBITDA': 'N/A',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '8.61%',
#   'Operating Margin': '10.79%',
#   'Return on Assets': '1.75%',
#   'Return on Equity': '6.06%',
#   'Revenue': '6.47B',
#   'Revenue Per Share': '39.82',
#   'Quarterly Revenue Growth': '41.90%',
#   'Gross Profit': '2.63B',
#   'EBITDA': '776M',
#   'Net Income Avi to Common': '557M',
#   'Diluted EPS': '3.42',
#   'Quarterly Earnings Growth': '112.40%',
#   'Total Cash': '706M',
#   'Total Cash Per Share': '4.39',
#   'Total Debt': '967M',
#   'Total Debt/Equity': '10.44',
#   'Current Ratio': '1.15',
#   'Book Value Per Share': '57.58',
#   'Operating Cash Flow': '1.35B',
#   'Levered Free Cash Flow': '548.5M',
#   'Beta (5Y Monthly)': '0.58',
#   '52-Week Change': '-32.94%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '118.19',
#   '52 Week Low': '46.07',
#   '50-Day Moving Average': '78.20',
#   '200-Day Moving Average': '72.15',
#   'Avg Vol (3 month)': '906.62k',
#   'Avg Vol (10 day)': '658.48k',
#   'Shares Outstanding': '160.85M',
#   'Float': '146.98M',
#   '% Held by Insiders': '6.57%',
#   '% Held by Institutions': '64.91%',
#   'Shares Short (Sep 14, 2020)': '5.09M',
#   'Short Ratio (Sep 14, 2020)': '9.29',
#   'Short % of Float (Sep 14, 2020)': '3.92%',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '3.16%',
#   'Shares Short (prior month Aug 13, 2020)': '4.59M',
#   'Forward Annual Dividend Rate': '2.4',
#   'Forward Annual Dividend Yield': '3.09%',
#   'Trailing Annual Dividend Rate': '2.32',
#   'Trailing Annual Dividend Yield': '2.98%',
#   '5 Year Average Dividend Yield': '2.66',
#   'Payout Ratio': '69.67%',
#   'Dividend Date': 'Oct 14, 2020',
#   'Ex-Dividend Date': 'Sep 14, 2020',
#   'Last Split Factor': '105:100',
#   'Last Split Date': 'Apr 03, 2005'},
#  {'name': 'CompX International Inc. (CIX)',
#   'Market Cap (intraday)': '186.14M',
#   'Enterprise Value': '123.69M',
#   'Trailing P/E': '13.72',
#   'Forward P/E': 'N/A',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '1.61',
#   'Price/Book': '1.12',
#   'Enterprise Value/Revenue': '1.07',
#   'Enterprise Value/EBITDA': '6.53',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '11.65%',
#   'Operating Margin': '13.12%',
#   'Return on Assets': '5.37%',
#   'Return on Equity': '8.33%',
#   'Revenue': '115.45M',
#   'Revenue Per Share': '9.28',
#   'Quarterly Revenue Growth': '-29.40%',
#   'Gross Profit': '38.96M',
#   'EBITDA': '18.93M',
#   'Net Income Avi to Common': '13.45M',
#   'Diluted EPS': '1.08',
#   'Quarterly Earnings Growth': '-57.80%',
#   'Total Cash': '62.45M',
#   'Total Cash Per Share': '5.02',
#   'Total Debt': 'N/A',
#   'Total Debt/Equity': 'N/A',
#   'Current Ratio': '8.23',
#   'Book Value Per Share': '13.35',
#   'Operating Cash Flow': '17.48M',
#   'Levered Free Cash Flow': '11.19M',
#   'Beta (5Y Monthly)': '0.22',
#   '52-Week Change': '0.80%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '17.57',
#   '52 Week Low': '10.53',
#   '50-Day Moving Average': '13.98',
#   '200-Day Moving Average': '14.07',
#   'Avg Vol (3 month)': '5.73k',
#   'Avg Vol (10 day)': '8.52k',
#   'Shares Outstanding': '12.45M',
#   'Float': '1.64M',
#   '% Held by Insiders': '86.80%',
#   '% Held by Institutions': '11.10%',
#   'Shares Short (Sep 14, 2020)': '32.87k',
#   'Short Ratio (Sep 14, 2020)': '9.45',
#   'Short % of Float (Sep 14, 2020)': '2.00%',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '0.26%',
#   'Shares Short (prior month Aug 13, 2020)': '31.25k',
#   'Forward Annual Dividend Rate': '0.4',
#   'Forward Annual Dividend Yield': '2.89%',
#   'Trailing Annual Dividend Rate': '0.34',
#   'Trailing Annual Dividend Yield': '2.46%',
#   '5 Year Average Dividend Yield': '1.66',
#   'Payout Ratio': '31.19%',
#   'Dividend Date': 'Sep 07, 2020',
#   'Ex-Dividend Date': 'Aug 30, 2020',
#   'Last Split Factor': 'N/A',
#   'Last Split Date': 'N/A'},
#  {'name': 'Cleveland-Cliffs Inc. (CLF)',
#   'Market Cap (intraday)': '2.28B',
#   'Enterprise Value': '6.85B',
#   'Trailing P/E': '95.17',
#   'Forward P/E': '15.43',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '0.70',
#   'Price/Book': '2.87',
#   'Enterprise Value/Revenue': '2.69',
#   'Enterprise Value/EBITDA': '30.20',
#   'Fiscal Year Ends': 'Dec 30, 2019',
#   'Most Recent Quarter': 'Jun 29, 2020',
#   'Profit Margin': '-0.86%',
#   'Operating Margin': '6.80%',
#   'Return on Assets': '1.82%',
#   'Return on Equity': '-0.26%',
#   'Revenue': '2.54B',
#   'Revenue Per Share': '8.21',
#   'Quarterly Revenue Growth': '47.00%',
#   'Gross Profit': '575.7M',
#   'EBITDA': '328.4M',
#   'Net Income Avi to Common': '-21.1M',
#   'Diluted EPS': '-0.07',
#   'Quarterly Earnings Growth': 'N/A',
#   'Total Cash': '73.7M',
#   'Total Cash Per Share': '0.19',
#   'Total Debt': '4.64B',
#   'Total Debt/Equity': '415.23',
#   'Current Ratio': '2.55',
#   'Book Value Per Share': '1.99',
#   'Operating Cash Flow': '116M',
#   'Levered Free Cash Flow': '-1.68B',
#   'Beta (5Y Monthly)': '2.27',
#   '52-Week Change': '-5.38%',
#   'S&P500 52-Week Change': '13.94%',
#   '52 Week High': '9.02',
#   '52 Week Low': '2.63',
#   '50-Day Moving Average': '6.39',
#   '200-Day Moving Average': '5.34',
#   'Avg Vol (3 month)': '10.01M',
#   'Avg Vol (10 day)': '15.5M',
#   'Shares Outstanding': '399.2M',
#   'Float': '392.7M',
#   '% Held by Insiders': '1.56%',
#   '% Held by Institutions': '61.95%',
#   'Shares Short (Sep 14, 2020)': '78.95M',
#   'Short Ratio (Sep 14, 2020)': '10.61',
#   'Short % of Float (Sep 14, 2020)': '24.30%',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '19.78%',
#   'Shares Short (prior month Aug 13, 2020)': '89.62M',
#   'Forward Annual Dividend Rate': 'N/A',
#   'Forward Annual Dividend Yield': 'N/A',
#   'Trailing Annual Dividend Rate': '0.18',
#   'Trailing Annual Dividend Yield': '2.56%',
#   '5 Year Average Dividend Yield': 'N/A',
#   'Payout Ratio': '300.00%',
#   'Dividend Date': 'Apr 14, 2020',
#   'Ex-Dividend Date': 'Apr 01, 2020',
#   'Last Split Factor': '2:1',
#   'Last Split Date': 'May 15, 2008'},
#  {'name': 'Canadian Imperial Bank of Commerce (CM)',
#   'Market Cap (intraday)': '33.80B',
#   'Enterprise Value': 'N/A',
#   'Trailing P/E': '11.76',
#   'Forward P/E': '9.68',
#   'PEG Ratio (5 yr expected)': 'N/A',
#   'Price/Sales': '2.39',
#   'Price/Book': '1.22',
#   'Enterprise Value/Revenue': 'N/A',
#   'Enterprise Value/EBITDA': 'N/A',
#   'Fiscal Year Ends': 'Oct 30, 2019',
#   'Most Recent Quarter': 'Jul 30, 2020',
#   'Profit Margin': '24.27%',
#   'Operating Margin': '0.00%',
#   'Return on Assets': '0.56%',
#   'Return on Equity': '10.16%',
#   'Revenue': 'N/A',
#   'Revenue Per Share': 'N/A',
#   'Quarterly Revenue Growth': '-5.80%',
#   'Gross Profit': '17.32B',
#   'EBITDA': 'N/A',
#   'Net Income Avi to Common': 'N/A',
#   'Diluted EPS': '8.76',
#   'Quarterly Earnings Growth': '-15.90%',
#   'Total Cash': 'N/A',
#   'Total Cash Per Share': 'N/A',
#   'Total Debt': 'N/A',
#   'Total Debt/Equity': 'N/A',
#   'Current Ratio': 'N/A',
#   'Book Value Per Share': '55.50',
#   'Operating Cash Flow': 'N/A',
#   'Levered Free Cash Flow': 'N/A',
#   'Beta (5Y Monthly)': '1.04',
#   '52-Week Change': 'N/A',
#   'S&P500 52-Week Change': 'N/A',
#   '52 Week High': '87.62',
#   '52 Week Low': '46.45',
#   '50-Day Moving Average': '76.75',
#   '200-Day Moving Average': '67.05',
#   'Avg Vol (3 month)': '377.63k',
#   'Avg Vol (10 day)': '387.07k',
#   'Shares Outstanding': '446.01M',
#   'Float': '445.78M',
#   '% Held by Insiders': '0.06%',
#   '% Held by Institutions': '52.26%',
#   'Shares Short (Sep 14, 2020)': '5.73M',
#   'Short Ratio (Sep 14, 2020)': '14.6',
#   'Short % of Float (Sep 14, 2020)': 'N/A',
#   'Short % of Shares Outstanding (Sep 14, 2020)': '1.29%',
#   'Shares Short (prior month Aug 13, 2020)': '4.86M',
#   'Forward Annual Dividend Rate': '4.37',
#   'Forward Annual Dividend Yield': '5.84%',
#   'Trailing Annual Dividend Rate': '4.00',
#   'Trailing Annual Dividend Yield': '5.35%',
#   '5 Year Average Dividend Yield': '4.94',
#   'Payout Ratio': '67.44%',
#   'Dividend Date': 'Oct 27, 2020',
#   'Ex-Dividend Date': 'Sep 24, 2020',
#   'Last Split Factor': 'N/A',
#   'Last Split Date': 'N/A'}]

# %%
tsx = pd.DataFrame(infos).iloc[:, :60]
tsx.head()
# Out:
#                                   name Market Cap (intraday) Enterprise Value  \
# 0            Abbott Laboratories (ABT)               178.68B          193.32B
# 1  Associated Capital Group, Inc. (AC)               778.64M          704.23M
# 2           Aurora Cannabis Inc. (ACB)               562.90M          833.34M
# 3     Agnico Eagle Mines Limited (AEM)                19.15B           20.56B
# 4         Aeterna Zentaris Inc. (AEZS)                21.54M           15.02M
#
#   Trailing P/E Forward P/E PEG Ratio (5 yr expected) Price/Sales Price/Book  \
# 0        58.67       23.15                      3.21        5.72       5.84
# 1        20.78         N/A                       N/A       26.69       0.91
# 2          N/A         N/A                       N/A        2.15       0.35
# 3        38.46       20.75                       N/A        7.20       3.67
# 4          N/A         N/A                       N/A        4.79      22.96
#
#   Enterprise Value/Revenue Enterprise Value/EBITDA  ...  \
# 0                     6.15                   26.60  ...
# 1                    24.04                  -25.21  ...
# 2                     2.99                   -0.26  ...
# 3                     7.71                   14.11  ...
# 4                    10.29                   -5.14  ...
#
#   Forward Annual Dividend Rate Forward Annual Dividend Yield  \
# 0                         1.44                         1.35%
# 1                          0.2                         0.57%
# 2                          N/A                           N/A
# 3                          0.8                         1.01%
# 4                          N/A                           N/A
#
#   Trailing Annual Dividend Rate Trailing Annual Dividend Yield  \
# 0                          1.40                          1.31%
# 1                          0.20                          0.55%
# 2                           N/A                            N/A
# 3                          0.70                          0.88%
# 4                           N/A                            N/A
#
#   5 Year Average Dividend Yield Payout Ratio Dividend Date Ex-Dividend Date  \
# 0                          1.90       79.07%  Nov 15, 2020     Oct 13, 2020
# 1                           N/A          N/A  Jun 29, 2020     Jun 14, 2020
# 2                           N/A        0.00%           N/A              N/A
# 3                          0.95       33.82%  Sep 14, 2020     Nov 23, 2020
# 4                           N/A        0.00%           N/A              N/A
#
#   Last Split Factor Last Split Date
# 0        10000:4798    Jan 01, 2013
# 1         1005:1000    Jul 28, 2020
# 2              1:12    May 10, 2020
# 3               N/A             N/A
# 4             1:100    Nov 19, 2015
#
# [5 rows x 60 columns]

# %%
tsx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 60 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   name                                          52 non-null     object
#  1   Market Cap (intraday)                         52 non-null     object
#  2   Enterprise Value                              52 non-null     object
#  3   Trailing P/E                                  52 non-null     object
#  4   Forward P/E                                   52 non-null     object
#  5   PEG Ratio (5 yr expected)                     52 non-null     object
#  6   Price/Sales                                   52 non-null     object
#  7   Price/Book                                    52 non-null     object
#  8   Enterprise Value/Revenue                      52 non-null     object
#  9   Enterprise Value/EBITDA                       52 non-null     object
#  10  Fiscal Year Ends                              52 non-null     object
#  11  Most Recent Quarter                           52 non-null     object
#  12  Profit Margin                                 52 non-null     object
#  13  Operating Margin                              52 non-null     object
#  14  Return on Assets                              52 non-null     object
#  15  Return on Equity                              52 non-null     object
#  16  Revenue                                       52 non-null     object
#  17  Revenue Per Share                             52 non-null     object
#  18  Quarterly Revenue Growth                      52 non-null     object
#  19  Gross Profit                                  52 non-null     object
#  20  EBITDA                                        52 non-null     object
#  21  Net Income Avi to Common                      52 non-null     object
#  22  Diluted EPS                                   52 non-null     object
#  23  Quarterly Earnings Growth                     52 non-null     object
#  24  Total Cash                                    52 non-null     object
#  25  Total Cash Per Share                          52 non-null     object
#  26  Total Debt                                    52 non-null     object
#  27  Total Debt/Equity                             52 non-null     object
#  28  Current Ratio                                 52 non-null     object
#  29  Book Value Per Share                          52 non-null     object
#  30  Operating Cash Flow                           52 non-null     object
#  31  Levered Free Cash Flow                        52 non-null     object
#  32  Beta (5Y Monthly)                             52 non-null     object
#  33  52-Week Change                                52 non-null     object
#  34  S&P500 52-Week Change                         52 non-null     object
#  35  52 Week High                                  52 non-null     object
#  36  52 Week Low                                   52 non-null     object
#  37  50-Day Moving Average                         52 non-null     object
#  38  200-Day Moving Average                        52 non-null     object
#  39  Avg Vol (3 month)                             52 non-null     object
#  40  Avg Vol (10 day)                              52 non-null     object
#  41  Shares Outstanding                            52 non-null     object
#  42  Float                                         52 non-null     object
#  43  % Held by Insiders                            52 non-null     object
#  44  % Held by Institutions                        52 non-null     object
#  45  Shares Short (Sep 14, 2020)                   49 non-null     object
#  46  Short Ratio (Sep 14, 2020)                    49 non-null     object
#  47  Short % of Float (Sep 14, 2020)               49 non-null     object
#  48  Short % of Shares Outstanding (Sep 14, 2020)  49 non-null     object
#  49  Shares Short (prior month Aug 13, 2020)       48 non-null     object
#  50  Forward Annual Dividend Rate                  52 non-null     object
#  51  Forward Annual Dividend Yield                 52 non-null     object
#  52  Trailing Annual Dividend Rate                 52 non-null     object
#  53  Trailing Annual Dividend Yield                52 non-null     object
#  54  5 Year Average Dividend Yield                 52 non-null     object
#  55  Payout Ratio                                  52 non-null     object
#  56  Dividend Date                                 52 non-null     object
#  57  Ex-Dividend Date                              52 non-null     object
#  58  Last Split Factor                             52 non-null     object
#  59  Last Split Date                               52 non-null     object
# dtypes: object(60)
# memory usage: 24.5+ KB

# %%
tsx.to_csv('tsx_stocks.csv')
